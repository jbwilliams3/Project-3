# %%
# Dependencies
import requests
import json
import os
import pandas as pd
import numpy as np
from config import gkey
import gmaps

# %%
# Google developer API key
gkey = "AIzaSyC8InpfcmbIEeFxvJmk5MeL4BuxOfl69kw"

# %%
# Set up the target URL for the geocode API call
def geocode_results(country):
    # print(country)
    target_url = (f'https://maps.googleapis.com/maps/api/geocode/json?address={country}&key={gkey}')
    response = requests.get(target_url).json()
    #print(target_url)
    return response

# %%
happiness_19_df = pd.read_csv(os.path.join('C:/Users/roelj/OneDrive/Desktop/school/Project-3/csv/happy_2019.csv'))
happiness_20_df = pd.read_csv(os.path.join('C:/Users/roelj/OneDrive/Desktop/school/Project-3/csv/happy_2020.csv'))
happiness_21_df = pd.read_csv(os.path.join('C:/Users/roelj/OneDrive/Desktop/school/Project-3/csv/happy_2021.csv'))
country_df = pd.read_csv(os.path.join(r'C:\Users\roelj\OneDrive\Desktop\school\Project-3\csv\countries.csv'))
country_location_df = pd.read_csv(os.path.join('C:/Users/roelj/OneDrive/Desktop/school/Project-3/csv/country_locations.csv'))

# %%
country_location_df["Lat"] = ""
country_location_df["Lng"] = ""
country_location_df.head()
#df2 = country_location_df.iloc[:5,:]
# Out:
#    Unnamed: 0.1  Unnamed: 0      country  country_id Lat Lng
# 0             0           0  Afghanistan           1
# 1             1           1      Albania           2
# 2             2           2      Algeria           3
# 3             3           3       Angola           4
# 4             4           4    Argentina           5

# %%
results = []
for index, row in country_location_df.iloc[0:5,:].iterrows():
            country = row['country']
            
            results.append(geocode_results(country))

# %%
for result in results:
       #if results:  # Check if results has elements
    data = result['results'][0]
    #print(data['geometry']['location']['lat'])
    country_location_df.loc[country_location_df['country'] == data['address_components'][0]['long_name'], "Lat"] = data['geometry']['location']['lat']
    
       # country_location_df.loc[index, "Lng"] = result[0]["geometry"]["location"]["lng"]
        #    else:
        #        print(f"No results found for {country}.")

# %%
# print for lng 
for result in results:
    data = result['results'][0]
    country_name = data['address_components'][0]['long_name']
    lng_value = data['geometry']['location']['lng']
    country_location_df.loc[country_location_df['country'] == country_name, "Lng"] = lng_value

# %%
country_location_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      country  country_id        Lat        Lng
# 0             0           0  Afghanistan           1   33.93911  67.709953
# 1             1           1      Albania           2  41.153332  20.168331
# 2             2           2      Algeria           3  28.033886   1.659626
# 3             3           3       Angola           4 -11.202692  17.873887
# 4             4           4    Argentina           5 -38.416097 -63.616672

# %%
country_location_df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'country', 'country_id', 'Lat', 'Lng'], dtype='object')

# %%
country_location_df.drop(columns = ['Unnamed: 0'],axis=1)
# Out:
#      Unnamed: 0.1      country  country_id        Lat        Lng
# 0               0  Afghanistan           1   33.93911  67.709953
# 1               1      Albania           2  41.153332  20.168331
# 2               2      Algeria           3  28.033886   1.659626
# 3               3       Angola           4 -11.202692  17.873887
# 4               4    Argentina           5 -38.416097 -63.616672
# ..            ...          ...         ...        ...        ...
# 161           161    Venezuela         162
# 162           162      Vietnam         163
# 163           163        Yemen         164
# 164           164       Zambia         165
# 165           165     Zimbabwe         166
#
# [166 rows x 5 columns]
